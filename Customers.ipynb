# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Customers.csv')
print(df)
# Out:
#     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]

# %%
# Step 1 : Initial Inspection

# %%
#Task 1 :  Finding the shape of the dataset , which is exactly number of row and columns 
df.shape   
# 200 rows and 4 columns
# Out:
# (200, 4)

# %%
#Task 2:  Finding the infomation of the dataset , which is exactly about the value's of dataset , type of values , and NULL values .
df.info
# Out:
# <bound method DataFrame.info of     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]>

# %%
#Task 3 : Next method is to describe about the dataset, which involves count, mean_value, standard_deviation.. etc.
df.describe
# Out:
# <bound method NDFrame.describe of     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]>

# %%
#Task4 Converting the Columns in the dataset to Python List , using columns.tolist() method .
df.columns.tolist()
# Out:
# ['CustomerID', 'CustomerName', 'Region', 'SignupDate']

# %%
#Task 5: Next step is to checking the NULL values in each columns and returning its sum , which is done using isnull().sum()
df.isnull().sum()
# Out:
# CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64

# %%
#Task 6 : Next case is to checking the unique values , using nunique() method
df.nunique()
# Out:
# CustomerID      200
# CustomerName    200
# Region            4
# SignupDate      179
# dtype: int64

# %%
# Step 2 :   Univariate Analysis (Single Variables)

# %%
quality_counts = df['Region'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
# Step 3: Bivariate Analysis for (understanding variable interactions and correlations effectively)

# %%
import seaborn as sns

# Bivariate Analysis: Region vs Sales (replace 'Sales' with the actual numerical column you're analyzing)

plt.figure(figsize=(8, 6))

# Boxplot to visualize the relationship between 'Region' and 'Sales'
sns.boxplot(x='Region', y='SignupDate', data=df, palette='Set2')

# Add title and labels
plt.title('Region vs SignupDate')
plt.xlabel('Region')
plt.ylabel('SignupDate')

plt.show()

# Alternatively, use a Violin plot for better distribution visualization
plt.figure(figsize=(8, 6))

sns.violinplot(x='Region', y='Sales', data=df, palette='Set2')

# Add title and labels
plt.title('Region vs Sales (Violin Plot)')
plt.xlabel('Region')
plt.ylabel('Sales')

plt.show()
# Out:
# C:\Users\Chandrahaas\AppData\Local\Temp\ipykernel_7556\1105946678.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='SignupDate', data=df, palette='Set2')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 20
#      17 # Alternatively, use a Violin plot for better distribution visualization
#      18 plt.figure(figsize=(8, 6))
# ---> 20 sns.violinplot(x='Region', y='Sales', data=df, palette='Set2')
#      22 # Add title and labels
#      23 plt.title('Region vs Sales (Violin Plot)')
#
# ...
