# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Products.csv')
print(df)
# Out:
#    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]

# %%
# Step 1 : Initial Inspection

# %%
#Task 1 :  Finding the shape of the dataset , which is exactly number of row and columns 
df.shape   
# in our data set it contains 100 rows and 4 columns
# Out:
# (100, 4)

# %%
#Task 2:  Finding the infomation of the dataset , which is exactly contains the value's of dataset , type of values , and NULL values .
df.info
# Out:
# <bound method DataFrame.info of    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]>

# %%
#Task 3 : Next method is to describe about the dataset, which involves count, mean_value, standard_deviation.. etc.
df.describe
# Out:
# <bound method NDFrame.describe of    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]>

# %%
#Task4 Converting the Columns in the dataset to Python List , using columns.tolist() method .
df.columns.tolist()
# Out:
# ['ProductID', 'ProductName', 'Category', 'Price']

# %%
#Task 5: Next step is to checking the NULL values in each columns and returning its sum , which is done using isnull().sum()
df.isnull().sum()
# Out:
# ProductID      0
# ProductName    0
# Category       0
# Price          0
# dtype: int64

# %%
# Step 2 :   Univariate Analysis (Single Variables)

# %%
quality_counts = df['Category'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
# Step 3: Bivariate Analysis for (understanding variable interactions and correlations effectively)

# %%
# Bivariate Analysis: Region vs Sales (replace 'Sales' with the actual numerical column you're analyzing)

plt.figure(figsize=(8, 6))

# Boxplot to visualize the relationship between 'Region' and 'Sales'
sns.boxplot(x='Category', y='Price', data=df, palette='Set2')

# Add title and labels
plt.title('Category vs Price')
plt.xlabel('Category')
plt.ylabel('Price')

plt.show()

# Alternatively, use a Violin plot for better distribution visualization
plt.figure(figsize=(8, 6))

sns.violinplot(x='Category', y='Price', data=df, palette='Set2')

# Add title and labels
plt.title('Category vs Price (Violin Plot)')
plt.xlabel('Category')
plt.ylabel('Price')

plt.show()
# Out:
# C:\Users\Chandrahaas\AppData\Local\Temp\ipykernel_4628\420714746.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Price', data=df, palette='Set2')
# C:\Users\Chandrahaas\AppData\Local\Temp\ipykernel_4628\420714746.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Category', y='Price', data=df, palette='Set2')
